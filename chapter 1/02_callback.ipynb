# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Input

model = Sequential()

model.add(Input(shape=(4,)))                            # input layer
model.add(Dense(50, activation="relu"))                 # hidden layer (50 = neuron count)
model.add(Dense(3, activation="softmax"))               # output layer (3 = neuron count)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
#model.summary()
# Out:
# 2025-09-11 22:48:50.332115: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M4 Pro
# 2025-09-11 22:48:50.332138: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 24.00 GB
# 2025-09-11 22:48:50.332145: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 8.00 GB
# 2025-09-11 22:48:50.332157: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-09-11 22:48:50.332166: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

iris = load_iris()
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.2, random_state=42)     # 총 150개의 데이터 중 30개는 테스트 데이터로 사용

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard  
path = 'model-{epoch:02d}-{val_accuracy:.4f}.h5'

# ModelCheckpoint : 모델 저장
checkpoint = ModelCheckpoint(path, save_best_only=True, monitor='val_accuracy', verbose=1)      

# EarlyStopping : 조기 종료
early_stopping = EarlyStopping(monitor='val_accuracy', patience=30)                                             # val_accuracy가 10번 연속 향상되지 않으면 학습 중단

# TensorBoard : 텐서보드 사용                                                                                       
tensor_board = TensorBoard(log_dir='./logs', histogram_freq=1, embeddings_freq=1)                               # log_dir : 로그 저장 위치, histogram_freq : 히스토그램 기록 빈도, embeddings_freq : 임베딩 기록 빈도
                                                                                                                # - 히스토그램 : weight, bias, - 임베딩 : loss, accuracy
# 모델 학습
model.fit(X_train, y_train, validation_split=0.2, epochs=100, batch_size=50, callbacks=[tensor_board])          # 총 120개의 데이터 중 24개는 검증 데이터로 사용
# model.fit(X_train, y_train, validation_split=0.2, epochs=100, batch_size=50, callbacks=[checkpoint, early_stopping])      

# 터미널에서 텐서보드 명령어 실행 후, 아래 주소로 접속                                                                                        
# tensorboard --logdir=logs
# http://localhost:6006/
# Out:
# Epoch 1/100
# 2025-09-11 22:48:50.833684: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 193ms/step - accuracy: 0.3646 - loss: 2.1896 - val_accuracy: 0.2083 - val_loss: 2.2607
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.3646 - loss: 1.9586 - val_accuracy: 0.2083 - val_loss: 1.9866
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.3646 - loss: 1.7485 - val_accuracy: 0.2083 - val_loss: 1.7386
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.3646 - loss: 1.5631 - val_accuracy: 0.2083 - val_loss: 1.5186
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.3646 - loss: 1.4011 - val_accuracy: 0.2083 - val_loss: 1.3341
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.3646 - loss: 1.2638 - val_accuracy: 0.2500 - val_loss: 1.1851
# Epoch 7/100
# ...
